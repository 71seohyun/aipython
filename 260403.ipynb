# %%
import random

answer = random.randint(1,100)
count = 0

while user != answer:
  user = int(input('추측값을 입력하시오: '))
  count += 1
  if user > answer:
    print('더 작은 수를 입력하시오')
  elif user < answer:
    print('더 큰 수를 입력하시오')
print('맞췄다')
print('총 시도 횟수:', count)
# Out:
# 추측값을 입력하시오: 29
# 더 큰 수를 입력하시오
# 추측값을 입력하시오: 60
# 더 작은 수를 입력하시오
# 추측값을 입력하시오: 40
# 더 큰 수를 입력하시오
# 추측값을 입력하시오: 50
# 더 큰 수를 입력하시오
# 추측값을 입력하시오: 55
# 더 큰 수를 입력하시오
# 추측값을 입력하시오: 57
# 더 작은 수를 입력하시오
# 추측값을 입력하시오: 56
# 맞췄다
# 총 시도 횟수: 7

# %%
num = int(input('약수를 구할 숫자를 입력하시오: '))

print('약수: ',end="")
for i in range(1, num+1):
  if num%i==0:
    print(i,end=" ")
# Out:
# 약수를 구할 숫자를 입력하시오: 12
# 약수: 1 2 3 4 6 12
